# %%
from data_collection.analysis import visualizations as vz
from data_collection.analysis.utils import get_tweets_from_json_file, create_pd_from_tweets, is_covid_related_tweet

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
MODE = "moh_engagement"

# %%
tweets = get_tweets_from_json_file(MODE)

# %%
print(len(tweets))
# Out:
# 3324

# %%
df = create_pd_from_tweets(tweets)

# %%
vz.summary(df)
# Out:
# Number of tweets: 1727
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1727 entries, 2020-10-30 04:37:47 to 2020-11-23 12:55:00
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   username       1727 non-null   object
#  1   user_id        1727 non-null   object
#  2   tweet_id       1727 non-null   object
#  3   text           1727 non-null   object
#  4   words          1727 non-null   object
#  5   retweet_count  1727 non-null   int64
#  6   reply_count    1727 non-null   int64
#  7   quote_count    1727 non-null   int64
#  8   like_count     1727 non-null   int64
#  9   engagement     1727 non-null   int64
# dtypes: int64(5), object(5)
# memory usage: 114.7+ KB
# Columns:
# None

# %%
# Distribution of tweets
vz.distribution_of_tweets(df, MODE)

# %%
# Comparing engagement
vz.compare_engagement(df, MODE)

# %%
covid_tweets = df[df['words'].apply(lambda t_words: is_covid_related_tweet(t_words))]

# %%
# Summary of COVID tweets and daily frequency
vz.summarise_covid_tweets(covid_tweets, MODE)
# Out:
# Number of COVID tweets: 48

# %%
# Distribution of covid tweets
vz.distribution_of_covid_tweets(df)

# %%
# Covid tweets by user
vz.covid_tweets_by_user(covid_tweets, MODE)

# %%
# Engagement on covid tweets
vz.engagement_on_covid_tweets(covid_tweets, MODE)

# %%
vz.highest_engagement_tweets(df)
# Out:
#                                             username    user_id  \
# created_time
# 2020-11-17 06:02:32  Walter Mwesigye @MwesigyeWalter  479217587
# 2020-11-19 12:55:37  Walter Mwesigye @MwesigyeWalter  479217587
# 2020-11-20 11:35:40  Walter Mwesigye @MwesigyeWalter  479217587
# 2020-11-18 13:43:23  Walter Mwesigye @MwesigyeWalter  479217587
# 2020-11-17 20:18:36    Duncan Abigaba @DuncanAbigaba  319711848
#
#                                 tweet_id  \
# created_time
# 2020-11-17 06:02:32  1328579252938297349
# 2020-11-19 12:55:37  1329407985026785282
# 2020-11-20 11:35:40  1329750253365551108
# 2020-11-18 13:43:23  1329057616052563968
# 2020-11-17 20:18:36  1328794690917953539
#
#                                                                   text  \
# created_time
# 2020-11-17 06:02:32  Just in: A team of Doctors from Mulago Special...
# 2020-11-19 12:55:37  Here is another military man shooting at civil...
# ...

# %%
vz.word_cloud(df)

# %%
vz.words_alongside_covid(covid_tweets)
